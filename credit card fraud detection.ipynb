# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#loading our data
credit = pd.read_csv("creditcard.csv")
print(credit.shape)
# Out:
# (284807, 31)

# %%
credit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# # Plotting histograms for finding out our most important features

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "Time") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V1") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V2") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V3") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V4") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V5") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V6") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V7") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V8") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V9") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V10") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V11") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V12") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V13") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V14") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V15") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V16") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V17") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V18") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V19") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V20") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V21") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V22") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V23") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V24") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V25") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V26") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V27") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "V28") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(credit, hue="Class", size=5) \
   .map(sns.distplot, "Amount") \
   .add_legend();
plt.show();
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # by histograms we can clearly see that features V3,V4,V9,V10,V11,V12 and V14 are our most important features

# %% [markdown]
# #  Now, applying KNN on creditcard dataset

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import cross_val_score
from collections import Counter
from sklearn.metrics import accuracy_score
from sklearn import cross_validation
# Out:
# c:\users\ashok\appdata\local\programs\python\python36\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#sampling our data
sampled_data=credit.sample(frac=1)

# %%
#as KNN has a very large time complexity and we dont have so much we computation power so using 20k points instead of whole data is better

final_data=sampled_data[0:50000]

# %%
#sorting our data with respect to time of each transaction 
final_data=final_data.sort_values('Time')

# %%
X = final_data[['V3','V4','V9','V10','V11','V12','V14' ]]
y = final_data['Class']

# %%
sampled_data=sampled_data.sort_values('Time')
X = sampled_data[['V3','V4','V9','V10','V11','V12','V14' ]]
y = sampled_data['Class']
X_train=X[0:256326]
X_test=X[256326:]
y_train=y[0:256326]
y_test=y[256326:]

myList = list(range(0,50))
neighbors = list(filter(lambda x: x % 2 != 0, myList))
cv_scores = []
# perform 10-fold cross validation
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
    cv_scores.append(scores.mean())

# changing to misclassification error
MSE = [1 - x for x in cv_scores]

# determining best k
optimal_k = neighbors[MSE.index(min(MSE))]
print('\nThe optimal number of neighbors is %d.' % optimal_k)
# Out:
# The optimal number of neighbors is 29.

# %%
#knn_optimal = KNeighborsClassifier(n_neighbors=optimal_k)
# fitting the model
X = sampled_data[['V3','V4','V9','V10','V11','V12','V14' ]]
y = sampled_data['Class']
X_train=X[0:256326]
X_test=X[256326:]
y_train=y[0:256326]
y_test=y[256326:]
knn_optimal = KNeighborsClassifier(n_neighbors= optimal_k , weights='distance')

# fitting the model
knn_optimal.fit(X_train, y_train)

# predict the response
pred = knn_optimal.predict(X_test)

# evaluate accuracy
acc = accuracy_score(y_test, pred) * 100
print('\nThe accuracy of the knn classifier for k = %d is %f%%' % (optimal_k, acc))
# Out:
# The accuracy of the knn classifier for k = 29 is 99.971911%

# %% [markdown]
# # Performing logistic regression

# %%
#logistic regression without doing any hyper paramter tuning
sampled_data=sampled_data.sort_values('Time')
from sklearn.linear_model import LogisticRegression
X = sampled_data[['V3','V4','V9','V10','V11','V12','V14' ]]
y = sampled_data['Class']
X_train=X[0:256326]
X_test=X[256326:]
y_train=y[0:256326]
y_test=y[256326:]
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
acc = accuracy_score(y_test, pred) * 100
print('\nThe accuracy for logistic regression is %f%%' % (acc))
# Out:
# The accuracy for logistic regression is 99.912222%

# %%
#logistic regression with hyper parameter tuning using random search to improve accuracy



from sklearn.model_selection import train_test_split
from sklearn.grid_search import RandomizedSearchCV

from sklearn.datasets import *
from sklearn.linear_model import LogisticRegression



tuned_parameters = {'C': np.random.uniform(10**-4,10**4,1000)}



#Using GridSearchCV
model =  RandomizedSearchCV(LogisticRegression(class_weight={1:10,0:1}), tuned_parameters, scoring = 'accuracy', cv=5)


model.fit(X_train, y_train)
                        

 
print(model.best_estimator_)
print(model.score(X_test, y_test))
# Out:
# LogisticRegression(C=7720.635895761293, class_weight={1: 10, 0: 1},
#           dual=False, fit_intercept=True, intercept_scaling=1,
#           max_iter=100, multi_class='ovr', n_jobs=1, penalty='l2',
#           random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#           warm_start=False)
# 0.9992626663389628

# %% [markdown]
# # Randomforest classifier

# %%
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier(n_estimators=10, max_depth=None,min_samples_split=2, random_state=10)
rf.fit(X_train,y_train)
scores = cross_val_score(rf, X_test, y_test)
scores.mean()
# Out:
# 0.9994733330940654

# %% [markdown]
# # Descision tree calssifier

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
scores = cross_val_score(clf, X_test, y_test)
scores.mean()
# Out:
# 0.9989817723843744

# %% [markdown]
# # SVM classifier

# %%
from sklearn import svm
C = 1.0
svc = svm.SVC(kernel='sigmoid', C=C).fit(X_train, y_train)

scores = cross_val_score(svc, X_test, y_test)
scores.mean()
# Out:
# 0.9991924539392042

# %% [markdown]
# # Creating a stacking model using all the models used above

# %%
def predict_(V3,V4,V9,V10,V11,V12,V14):
    
   # global pred,X_test
    from collections import Counter
    X_test = [[V3,V4,V9,V10,V11,V12,V14]]
    pred1 = model.predict(X_test)
    pred2= knn_optimal.predict(X_test)
    pred3 = rf.predict(X_test)
    pred4 = clf.predict(X_test)
    pred5= svc.predict(X_test)

    lst=[pred1[0],pred2[0],pred3[0],pred4[0],pred5[0]]
    

    data = Counter(lst)
    final_pred=data.most_common(1)[0][0]
    print(final_pred)
    return final_pred                                             #will return the final predicted value

# %% [markdown]
# # Creating GUI

# %%
from tkinter import *
window = Tk(className=" Credit card fraud detection")
window.config(background='brown')

def prediction_():
    pred = predict_(float(text1.get()),float(text2.get()),float(text3.get()),float(text4.get()),float(text5.get()),float(text6.get()),float(text7.get()))
    if pred==1:
        l9 = Label(window,text='Fraud')
    else:
        l9 = Label(window,text='No Fraud')
    
    l9.config(width=20,font=("Times New Roman",20),background='chocolate1')
    l9.grid(row=17,column=0,padx=10,pady=10)
        
def Knn_():
    pred = Knn(float(text1.get()),float(text2.get()),float(text3.get()),float(text4.get()),float(text5.get()),float(text6.get()),float(text7.get()))
    if pred==1:
        l9 = Label(window,text='Fraud')
    else:
        l9 = Label(window,text='No Fraud')
    
    l9.config(width=20,font=("Times New Roman",20),background='chocolate1')
    l9.grid(row=17,column=0,padx=10,pady=10)



l0 = Label(window,text='CREDIT CARD FRAUD DETECTION')
l0.config(width=30,font=("Times New Roman",40),background='brown3')
l0.grid(row=0,column=0,columnspan=6,padx=200,pady=40)

l1 = Label(window,text='V3')
l1.config(width=20,font=("Times New Roman",),background='brown3')
l1.grid(row=9,column=0,pady=20)

l2 = Label(window,text='V4')
l2.config(width=20,font=("Times New Roman",),background='brown3')
l2.grid(row=10,column=0,padx=10,pady=20)

l3 = Label(window,text='V9')
l3.config(width=20,font=("Times New Roman",),background='brown3')
l3.grid(row=11,column=0,padx=10,pady=20)

l4 = Label(window,text='V10')
l4.config(width=20,font=("Times New Roman",),background='brown3')
l4.grid(row=12,column=0,pady=20)

l5 = Label(window,text='V11')
l5.config(width=20,font=("Times New Roman",),background='brown3')
l5.grid(row=13,column=0,pady=20)

l6 = Label(window,text='V12')
l6.config(width=20,font=("Times New Roman",),background='brown3')
l6.grid(row=14,column=0,padx=10,pady=20)

l7 = Label(window,text='V14')
l7.config(width=20,font=("Times New Roman",),background='brown3')
l7.grid(row=15,column=0,padx=10,pady=20)

l8 = Label(window,text='Result')
l8.config(width=20,font=("Times New Roman",),background='gray')
l8.grid(row=16,column=0,padx=10,pady=40)




text1=DoubleVar()
e1=Entry(window,textvariable=text1)
e1.grid(row=9,column=1,padx=10,pady=20)

text2=DoubleVar()
e2=Entry(window,textvariable=text2)
e2.grid(row=10,column=1,padx=10,pady=20)

text3=DoubleVar()
e3=Entry(window,textvariable=text3)
e3.grid(row=11,column=1,padx=10,pady=20)

text4=DoubleVar()
e4=Entry(window,textvariable=text4)
e4.grid(row=12,column=1,padx=10,pady=20)


text5=DoubleVar()
e5=Entry(window,textvariable=text5)
e5.grid(row=13,column=1,padx=10,pady=20)

text6=DoubleVar()
e6=Entry(window,textvariable=text6)
e6.grid(row=14,column=1,padx=10,pady=20)

text7=DoubleVar()
e6=Entry(window,textvariable=text7)
e6.grid(row=15,column=1,padx=10,pady=20)




b1=Button(window,text='PREDICT',font=("Times New Roman",13),width=15,background='pink3',command=prediction_)
b1.grid(row=10,column=2,padx=10,pady=20)






b2=Button(window,text="Close", width=15,font=("Times New Roman",13),background='pink3',command=window.destroy)
b2.grid(row=14,column=2,padx=10,pady=20)


window.mainloop()
# Out:
# 0

# %%
#data for checking that model working good for fraud data points
df=final_data.loc[final_data['Class'] == 1]
df=df[['V3','V4','V9','V10','V11','V12','V14' ]]
df
# Out:
#               V3         V4        V9        V10        V11        V12  \
# 541    -1.609851   3.997906 -2.770089  -2.772272   3.202033  -2.899907
# 623     1.088463   2.288644 -0.270953  -0.838587  -0.414575  -0.503141
# 4920   -0.359745   2.330243 -0.238253  -1.525412   2.032912  -6.560124
# 6108   -2.592844   2.679787 -0.247768  -4.801637   4.895844 -10.912819
# 6329   -4.304597   4.732795 -1.282858  -2.447469   2.101344  -4.609628
# 6331   -6.240697   6.675732 -2.795892  -6.187891   5.664395  -9.854485
# 6334   -6.560600   6.348557 -3.139409  -6.045468   6.754625  -8.948179
# 6336   -5.775935   6.078266 -2.214311  -5.134454   4.560720  -8.873748
# 6338   -5.615159   6.047445 -2.678679  -4.959493   6.439053  -7.520117
# 6427   -5.329976   4.007683 -0.486097  -4.624985   5.588724  -7.148243
# 6446   -5.234513   4.416661 -0.166199  -5.009249   4.675729  -8.167188
# 6472   -4.769752   3.819195  0.415382  -3.955812   3.572055  -7.186452
# ...

# %%
df1=credit.head()

# %%
#data for checking that model working good for non fraud data points
df1=df1[['V3','V4','V9','V10','V11','V12','V14','Class' ]]
df1
# Out:
#          V3        V4        V9       V10       V11       V12       V14  Class
# 0  2.536347  1.378155  0.363787  0.090794 -0.551600 -0.617801 -0.311169      0
# 1  0.166480  0.448154 -0.255425 -0.166974  1.612727  1.065235 -0.143772      0
# 2  1.773209  0.379780 -1.514654  0.207643  0.624501  0.066084 -0.165946      0
# 3  1.792993 -0.863291 -1.387024 -0.054952 -0.226487  0.178228 -0.287924      0
# 4  1.548718  0.403034  0.817739  0.753074 -0.822843  0.538196 -1.119670      0
